# %%
# %pip install yfinance matplotlib pandas
# Out:
# Collecting yfinance
#   Using cached yfinance-1.2.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (52 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-4.0.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: websockets>=13.0 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: cffi>=1.12.0 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.8.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from pandas) (2025.2)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ft312/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Using cached yfinance-1.2.0-py2.py3-none-any.whl (130 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Downloading matplotlib-3.10.8-cp312-cp312-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 9.8 MB/s  0:00:00 eta 0:00:01m
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 7.8 MB/s  0:00:00m eta 0:00:01
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading kiwisolver-1.4.9-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
# Using cached peewee-4.0.0-py3-none-any.whl (139 kB)
# Downloading pillow-12.1.1-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 7.6 MB/s  0:00:00 eta 0:00:01m
# Downloading protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: peewee, multitasking, soupsieve, pyparsing, protobuf, pillow, kiwisolver, frozendict, fonttools, cycler, contourpy, matplotlib, curl_cffi, beautifulsoup4, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [yfinance]/15 [yfinance]b]
# Successfully installed beautifulsoup4-4.14.3 contourpy-1.3.3 curl_cffi-0.13.0 cycler-0.12.1 fonttools-4.61.1 frozendict-2.4.7 kiwisolver-1.4.9 matplotlib-3.10.8 multitasking-0.0.12 peewee-4.0.0 pillow-12.1.1 protobuf-6.33.5 pyparsing-3.3.2 soupsieve-2.8.3 yfinance-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = "GOOG"

data = yf.download(ticker, period='1y')

print(data.head())

plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Close'], label='GOOG Close Price', color='blue')

plt.title(f'{ticker} Stock Price - Last 1 Year', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2025-02-24  180.487350  184.372220  180.178555  183.087230  18734000
# 2025-02-25  176.682159  180.059012  176.084495  179.456363  20832500
# 2025-02-26  174.022522  177.389419  172.916826  176.258826  23637200
# 2025-02-27  169.549927  175.905175  169.093695  175.257701  25930500
# 2025-02-28  171.552139  171.831052  167.736990  169.639587  30049800
